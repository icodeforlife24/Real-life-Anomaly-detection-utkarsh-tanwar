# %% [markdown]
# # Tracking + Anomaly Detection in Avenue Dataset

# %% [markdown]
# ## Dataset used: **Avenue Dataset for Abnormal Event Detection**
#
#
#
# This dataset accompanies paper "Abnormal Event Detection at 150 FPS in Matlab, Cewu Lu, Jianping Shi, Jiaya Jia, International Conference on Computer Vision, (ICCV), 2013"

# %% [markdown]
# ### Importing required libraries

# %%
import os
import cv2
import torch
import shutil
import random
import numpy as np
from glob import glob
from tqdm import tqdm
import matplotlib.pyplot as plt

np.random.seed(42)

# %% [markdown]
# ### Mount google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ```
# Avenue Dataset
#  └── testing_videos
#  └── testing_vol
#  └── training_videos
#  └── training_vol
#
# ```

# %%
if not os.path.exists('yolov5'):
    # !git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17516, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 17516 (delta 7), reused 0 (delta 0), pack-reused 17496 (from 4)
# Receiving objects: 100% (17516/17516), 16.60 MiB | 27.08 MiB/s, done.
# Resolving deltas: 100% (11995/11995), done.

# %%
# %cd yolov5/
# !pwd
# Out:
# /content/yolov5/yolov5
# /content/yolov5/yolov5

# %%
# !pip install -r requirements.txt

# %%
# %cd /content
# Out:
# /content

# %% [markdown]
# #### Use the best YOLOv5 model u have trained

# %%
model_path ='/content/drive/MyDrive/MOT17-RESULTS/results_3/weights/best.pt'

# %%
# Load YOLOv5 model
model = torch.hub.load('yolov5', 'custom', path= model_path, source='local')
model.conf = 0.25
model.iou = 0.45
# Out:
# YOLOv5 🚀 v7.0-422-g2540fd4c Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
#
# Fusing layers...
# Model summary: 212 layers, 20852934 parameters, 0 gradients, 47.9 GFLOPs
# Adding AutoShape...

# %%
! pip install deep_sort_realtime opencv-python tqdm
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 72.2 MB/s eta 0:00:00
# ...

# %%
from deep_sort_realtime.deepsort_tracker import DeepSort

# %%
output_video_folder ="/content/drive/MyDrive/anomaly_result"
os.makedirs(output_video_folder, exist_ok = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3-2977100814.py in <cell line: 0>()
#       1 output_video_folder ="/content/drive/MyDrive/anomaly_result"
# ----> 2 os.makedirs(output_video_folder, exist_ok = True)
#
# NameError: name 'os' is not defined

# %%
output_video_path ="/content/drive/MyDrive/anomaly_result/16.avi"
input_video_path  ='/content/drive/MyDrive/Avenue_Dataset/Avenue Dataset/testing_videos/16.avi'

# %%
N_history =20          # how many frames to use for velocity calc
smoothing_frames=20   # Smoothing: once RED, stay RED for N frames
velocity_threshold=200  # Velocity threshold (pixels per second)

# %% [markdown]
# ### Tune the below parameters

# %%
# Init DeepSORT tracker
tracker = DeepSort(max_age=30)

# Input video
cap = cv2.VideoCapture(input_video_path)

# Get video info
fps = cap.get(cv2.CAP_PROP_FPS)
width  = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
print(f"Video: {fps} FPS, {width}x{height}, {frame_count} frames")

# Prepare output video writer
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter(output_video_path, fourcc, fps, (width, height))

import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

read_count = 0
frame_idx = 0
pbar = tqdm(total=frame_count)

track_memory = {}     # Memory for tracking: store last N positions
anomaly_memory = {}   # store last anomaly state (for smoothing)

saved_anomaly_ids = set()   # to avoid saving duplicates
max_anomaly_frames = 500    # limit on the frames saved

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # YOLO Inference
    results = model(frame)
    detections = results.xyxy[0].cpu().numpy()  # (xmin, ymin, xmax, ymax, conf, cls)

    # Format detections for DeepSORT
    formatted_detections = []
    for d in detections:
        xmin, ymin, xmax, ymax, conf, cls = d
        width_box = xmax - xmin
        height_box = ymax - ymin
        box = [xmin, ymin, width_box, height_box]
        formatted_detections.append([box, conf])

    # Update tracker
    tracks = tracker.update_tracks(formatted_detections, frame=frame)

    # Draw tracks
    for track in tracks:
        if not track.is_confirmed():
            continue

        track_id = track.track_id   # unique ID assigned to the pedestrian
        ltrb = track.to_ltrb()      # gives [left, top, right, bottom] of bounding box
        xmin, ymin, xmax, ymax = map(int, ltrb)

        # Center point
        center_x = (xmin + xmax) / 2
        center_y = (ymin + ymax) / 2

        # Update history
        track_memory.setdefault(track_id, []).append((frame_idx, center_x, center_y))
        track_memory[track_id] = track_memory[track_id][-N_history:]

        # Calculate velocity
        if len(track_memory[track_id]) >= 2:
            f1, x1, y1 = track_memory[track_id][0]
            f2, x2, y2 = track_memory[track_id][-1]

            dt = (f2 - f1) / fps  # time in seconds
            dx = x2 - x1
            dy = y2 - y1
            distance = np.sqrt(dx**2 + dy**2)

            velocity = distance / (dt + 1e-6)  # avoid zero div

            # Anomaly flag
            if velocity > velocity_threshold:
                anomaly = True
            else:
                anomaly = False
        else:
            anomaly = False


        if anomaly:
            anomaly_memory[track_id] = frame_idx  # mark when anomaly seen

        if track_id in anomaly_memory:
            if frame_idx - anomaly_memory[track_id] <= smoothing_frames:
                anomaly = True  # force RED

        # Drawing boxes only around the anomaly
        if anomaly:

          label = f"ID {track_id} {'ANOMALY'}"
          color = (0, 0, 255)

          cv2.rectangle(frame, (xmin, ymin), (xmax, ymax), color, 1)
          cv2.putText(frame, label, (xmin, ymin - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.6, color, 2)


    # Write frame
    out.write(frame)

    frame_idx += 1
    read_count += 1
    pbar.update(1)

pbar.close()
cap.release()
out.release()

print(f"Frames read: {read_count} / {frame_count}")
print(f"\n DONE — output saved to: {output_video_path}")
# Out:
# Video: 25.0 FPS, 640x360, 740 frames
# 100%|██████████| 740/740 [01:51<00:00,  6.63it/s]
# Frames read: 740 / 740
#
#  DONE — output saved to: /content/drive/MyDrive/anomaly_result/16.avi

# %% [markdown]
# ####  Check for different test videos
